# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing]
# - **Nama:** Zalfa Nazhifah Huwaida
# - **Email:** zalfanazhifah.h@gmail.com
# - **ID Dicoding:** zalfahuwaida

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pada bulan berapa keadaan persewaan sepeda paling sepi?
# - Apakah ada lonjakan yang drastis pada tanggal tertentu? pada tanggal berapa terdapat lonjakan drastis?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv('day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv('hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.isna().sum()
# Out:
# Jumlah duplikasi:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %%
#Convert dateday to datetime data type

day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %%
day_df.head()
hour_df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Correct the values
day_df['weekday'] = day_df['dteday'].dt.day_name()
hour_df['weekday'] = hour_df['dteday'].dt.day_name()

# %%
day_df['mnth'] = day_df['dteday'].dt.month_name()
hour_df['mnth'] = hour_df['dteday'].dt.month_name()

# %%
day_df['yr'] = day_df['dteday'].dt.year
hour_df['yr'] = hour_df['dteday'].dt.year

# %%
# Count the tempt
day_df['temp'] = day_df['temp']*41
hour_df['temp'] = hour_df['temp']*41

# %%
# Count the atempt
day_df['atemp'] = day_df['atemp']*50
hour_df['atemp'] = hour_df['atemp']*50

# %%
# Replace the seasons value in day_df
def find_season(season):
    season_string = {1:'Winter', 2:'Spring', 3:'Summer', 4:'Fall'}
    return season_string.get(season)

season_list = []

for season in day_df['season']:
    season = find_season(season)
    season_list.append(season)

day_df['season'] = season_list

# %%
# Replace the seasons value in hour_df
def find_season(season):
    season_string = {1:'Winter', 2:'Spring', 3:'Summer', 4:'Fall'}
    return season_string.get(season)

season_list = []

for season in hour_df['season']:
    season = find_season(season)
    season_list.append(season)

hour_df['season'] = season_list

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore day_df

# %%
# Statistic parameter day_df
day_df.describe(include="all")
# Out:
#            instant               dteday season           yr     mnth  \
# count   731.000000                  731      0   731.000000      731
# unique         NaN                  NaN      0          NaN       12
# top            NaN                  NaN    NaN          NaN  January
# freq           NaN                  NaN    NaN          NaN       62
# mean    366.000000  2012-01-01 00:00:00    NaN  2011.500684      NaN
# min       1.000000  2011-01-01 00:00:00    NaN  2011.000000      NaN
# 25%     183.500000  2011-07-02 12:00:00    NaN  2011.000000      NaN
# 50%     366.000000  2012-01-01 00:00:00    NaN  2012.000000      NaN
# 75%     548.500000  2012-07-01 12:00:00    NaN  2012.000000      NaN
# max     731.000000  2012-12-31 00:00:00    NaN  2012.000000      NaN
# std     211.165812                  NaN    NaN     0.500342      NaN
#
#            holiday   weekday  workingday  weathersit         temp  \
# count   731.000000       731  731.000000  731.000000   731.000000
# ...

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])

# %%
day_df['month'] = day_df['dteday'].dt.month

# %%
# Bike sharing by month
day_df.groupby(by="month").agg({
    "cnt": ["sum"]
})
# Out:
#           cnt
#           sum
# month
# 1      134933
# 2      151352
# 3      228920
# 4      269094
# 5      331686
# 6      346342
# 7      344948
# 8      351194
# 9      345991
# 10     322352
# 11     254831
# 12     211036

# %%
# Bike sharing by month (sort by most)
day_df.groupby(by="month").cnt.sum().sort_values(ascending=False).reset_index().head(12)
# Out:
#     month     cnt
# 0       8  351194
# 1       6  346342
# 2       9  345991
# 3       7  344948
# 4       5  331686
# 5      10  322352
# 6       4  269094
# 7      11  254831
# 8       3  228920
# 9      12  211036
# 10      2  151352
# 11      1  134933

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Explore Data hour_df

# %%
# Statistic parameter hour_df
hour_df.describe(include="all")
# Out:
#            instant                         dteday season            yr   mnth  \
# count   17379.0000                          17379      0  17379.000000  17379
# unique         NaN                            NaN      0           NaN     12
# top            NaN                            NaN    NaN           NaN    May
# freq           NaN                            NaN    NaN           NaN   1488
# mean     8690.0000  2012-01-02 04:08:34.552045568    NaN   2011.502561    NaN
# min         1.0000            2011-01-01 00:00:00    NaN   2011.000000    NaN
# 25%      4345.5000            2011-07-04 00:00:00    NaN   2011.000000    NaN
# 50%      8690.0000            2012-01-02 00:00:00    NaN   2012.000000    NaN
# 75%     13034.5000            2012-07-02 00:00:00    NaN   2012.000000    NaN
# max     17379.0000            2012-12-31 00:00:00    NaN   2012.000000    NaN
# std      5017.0295                            NaN    NaN      0.500008    NaN
#
# ...

# %%
# Bike sharing by hour
hour_df.groupby(by="hr").agg({
    "cnt": ["sum"]
})
# Out:
#        cnt
#        sum
# hr
# 0    39130
# 1    24164
# 2    16352
# 3     8174
# 4     4428
# 5    14261
# 6    55132
# 7   154171
# 8   261001
# 9   159438
# 10  126257
# 11  151320
# 12  184414
# 13  184919
# 14  175652
# 15  183149
# 16  227748
# 17  336860
# 18  309772
# 19  226789
# 20  164550
# 21  125445
# 22   95612
# 23   63941

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Pada bulan berapa keadaan persewaan sepedah paling sepi?

# %%
day_df.groupby(by="month").agg({
    "cnt": ["sum"]
})
# Out:
#           cnt
#           sum
# month
# 1      134933
# 2      151352
# 3      228920
# 4      269094
# 5      331686
# 6      346342
# 7      344948
# 8      351194
# 9      345991
# 10     322352
# 11     254831
# 12     211036

# %%
grouped_data = day_df.groupby(by=["month"])['cnt'].sum().sort_values(ascending=False).reset_index()

# Create the barchart
plt.figure(figsize=(10,6))
sn.barplot(x="month", y="cnt", data=grouped_data, hue=None, palette='Blues_d', legend=False)

# Add label and title
plt.xlabel("Month")
plt.ylabel("Total Count")
plt.title("Total Bikeshare Users per Month")

# Show plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-177-916bedd144df>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x="month", y="cnt", data=grouped_data, hue=None, palette='Blues_d', legend=False)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# ### Pertanyaan 2: Apakah ada lonjakan yang drastis pada tanggal tertentu? pada tanggal berapa terdapat lonjakan drastis?

# %%
plt.figure(figsize=(16,6))

# Create a line plot using the sns.lineplot() function
sn.lineplot(x="dteday", y="cnt", data=day_df, color='blue')

# Add labels and a title to the plot
plt.xlabel("Date")
plt.ylabel("Count")
plt.title("Bikeshare users")

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Count the change
day_df['change'] = day_df['cnt'].diff()

# Max Spike
max_spike = day_df.loc[day_df['change'].idxmax()]

# Create Plot
plt.figure(figsize=(16,6))
sn.lineplot(x="dteday", y="cnt", data=day_df, color='blue')

# Mark the max spike
plt.axvline(x=max_spike['dteday'], color='red', linestyle='--', alpha=0.7)
plt.text(max_spike['dteday'], max_spike['cnt'],
         f"{max_spike['dteday'].strftime('%Y-%m-%d')}",  # Menampilkan tanggal lonjakan
         color='black', ha='center', va='bottom', fontsize=10, backgroundcolor='white')

# Add label and title
plt.xlabel("Date")
plt.ylabel("Count")
plt.title("Bikeshare users")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 : Keadaan persewaan sepeda paling sepi ada pada bulan 1
# - Conclution pertanyaan 2 : Ada, Lonjakan yang drastis berada pada tanggal 31 Oktober 2012

# %%
hour_df.to_csv("hour_data.csv", index=False)

# %%
day_df.to_csv("day_data.csv", index=False)
